# %%
import matplotlib.pyplot as plt
import numpy as np

h = 0.001 ##Took this from notes, AI utilized to input new ODE , graph looked weird and so followed advice to switch h to .001. 
t_start, t_end = 0, 2
num_steps = int((t_end - t_start) / h)
t_values = np.linspace(t_start, t_end, num_steps + 1)
y_values = np.zeros(num_steps + 1)
y_values[0] = 0

def f(t, y):
    return -1000*y + 3000 - 2000*np.exp(-t)

for i in range(num_steps):
    y_values[i + 1] = y_values[i] + h * f(t_values[i], y_values[i])

y_analytical = 3 - 0.998*np.exp(-1000*t_values) - 2.002*np.exp(-t_values)

plt.plot(t_values, y_values, label="Euler's Forward")
plt.plot(t_values, y_analytical, label="Analytical", linestyle='--')
plt.xlabel('t')
plt.ylabel('y')
plt.legend()
plt.ylim(-5, 10) ##Used AI to produce this line in order for the graph to look nicer
plt.show()
