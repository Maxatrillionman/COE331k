# %%
import numpy as np  ##from notes 
import matplotlib.pyplot as plt

# Parameters
k = 1.0  # Spring constant
h_values = [0.01, 0.1, 0.5, 1.0]  # Different step sizes to test stability
t_start = 0   # Start time
t_end = 20    # End time
y_0 = 1.0     # Initial displacement
v_0 = 0.0     # Initial velocity

# Function to apply Euler's Method for given step size
def euler_method(h, k, t_start, t_end, y_0, v_0):
    t_values = np.arange(t_start, t_end + h, h)
    y_values = np.zeros(len(t_values))
    v_values = np.zeros(len(t_values))

    # Set initial conditions
    y_values[0] = y_0
    v_values[0] = v_0

    for i in range(1, len(t_values)):
        y_n = y_values[i - 1]
        v_n = v_values[i - 1]

        # Update equations for Euler's Method
        y_values[i] = y_n + h * v_n
        v_values[i] = v_n + h * (-k * y_n)

    return t_values, y_values

# Construct the coefficient matrix for Euler's Method
# State vector: [y, v], so A maps [y_n, v_n] -> [y_{n+1}, v_{n+1}]
def get_coefficient_matrix(h, k):
    A = np.array([[1,    h ],
                  [-k*h, 1 ]])
    return A

# Plot results for different step sizes
plt.figure(figsize=(12, 6))

for h in h_values:
    # Build matrix and compute eigenvalues
    A = get_coefficient_matrix(h, k)
    eigenvalues = np.linalg.eigvals(A)
    max_eig_magnitude = np.max(np.abs(eigenvalues))

    # Display step size and stability
    print(f"Step size h = {h}")
    if max_eig_magnitude < 1:
        print("Solution is Stable")
    else:
        print("Solution may not be Entirely Stable ;)")
    print(f"  Eigenvalues: {eigenvalues}, Max |λ| = {max_eig_magnitude:.4f}\n")

    t, y = euler_method(h, k, t_start, t_end, y_0, v_0)
    plt.plot(t, y, label=f'Euler\'s Method (h={h})')

plt.xlabel('Time (t)')
plt.ylabel('Displacement (y)')
plt.title('Stability Analysis of Euler\'s Method for a 2nd Order ODE')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Step size h = 0.01
# Solution may not be Entirely Stable ;)
#   Eigenvalues: [1.+0.01j 1.-0.01j], Max |λ| = 1.0000
#
# Step size h = 0.1
# Solution may not be Entirely Stable ;)
#   Eigenvalues: [1.+0.1j 1.-0.1j], Max |λ| = 1.0050
#
# Step size h = 0.5
# Solution may not be Entirely Stable ;)
#   Eigenvalues: [1.+0.5j 1.-0.5j], Max |λ| = 1.1180
#
# Step size h = 1.0
# Solution may not be Entirely Stable ;)
#   Eigenvalues: [1.+1.j 1.-1.j], Max |λ| = 1.4142
