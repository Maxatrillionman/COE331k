# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 2 * np.pi, 50)
plt.plot(x, np.sin(x))
plt.show()

# %%
plt.plot(x, np.sin(x), 
         x, np.sin(2 * x))
plt.show()

# %%
plt.plot(x, np.sin(x), 'r-o', 
        x, np.cos(x), 'gs')
plt.show()

# %%
plt.subplot(2, 1, 1) # (row, column, active area)
plt.plot(x, np.sin(x), 'r')
plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x), 'g')
plt.show(0)

# %%
y = np.sin(x)
plt.scatter(x,y)
plt.show()

# %%
x = np.random.rand(1000)
y = np.random.rand(1000)
size = np.random.rand(1000) * 50
color = np.random.rand(1000)
plt.scatter(x, y, size, color)
plt.colorbar()
plt.show()

# %%
plt.hist(x, 50)
plt.show()

# %%
z1 = np.empty([2001, 2001])
im = plt.imshow(z1, cmap='hot')
fig = plt.colorbar(im, orientation='horizontal')
plt.show(fig)

# %%
def f1(x, y):
    return (x*x + y*y)

x = np.linspace(-10, 10, 2000)
y = np.linspace(-10, 10, 2000)

X, Y = np.meshgrid(x, y)
Z = f1(X, Y)

# %%
fig1 = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 50, cmap='hot')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z');
ax.view_init(45, 0)

# %%
##Below is the combined plot -- was sick on Tuesday

# %%
plt.plot(x, np.sin(x), 'b-o')

x = np.random.rand(1000)
y = np.random.rand(1000)
size = np.random.rand(1000) * 50
color = np.random.rand(1000)
plt.scatter(x, y, size, color)
plt.colorbar()


fig = plt.colorbar(im, orientation='horizontal')


plt.hist(.5)
plt.hist(.3)
plt.hist(.8)



plt.show()

# %%
fig1 = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 5, cmap='hot')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z');
ax.view_init(0, 10)

plt.plot(x, np.sin(x), 'b-o')

x = np.random.rand(1000)
y = np.random.rand(1000)
size = np.random.rand(1000) * 50
color = np.random.rand(1000)
plt.scatter(x, y, size, color)
plt.colorbar()


fig = plt.colorbar(im, orientation='horizontal')
 

plt.hist(.5)
plt.hist(.3)
plt.hist(.8)



plt.show()
