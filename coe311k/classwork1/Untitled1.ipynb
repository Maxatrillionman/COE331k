# %%
import numpy as np 

v1 = np.array([1, 2, 3])
v2 = np.array([4, 5, 6])
print(v1)
print(v2)
# Out:
# [1 2 3]
# [4 5 6]

# %%
v_add = v1 + v2
v_sub = v1 - v2
scalar = 2
v_scaled = scalar*v1

# %%
dot_product =
