# %%
import numpy as np ##From lectures 1:1 
import matplotlib.pyplot as plt
import time


def naive_matrix_multiplication(A, B):
    n = len(A)
    C = [[0] * n for _ in range(n)]

    for i in range(n):
        for j in range(n):
            for k in range(n):
                C[i][j] += A[i][k] * B[k][j]
    

    return C

# %%
i = 3
naive_times = []
numpy_times = []
sizes = []
while(i <= 384):
    
    print("i = " + str(i))
    a = np.random.rand(i,i)
    b = np.random.rand(i,i)
  
    start = time.time()
    naive_matrix_multiplication(a.tolist(), b.tolist())
    end = time.time()
    naive_times.append(end - start)

    
    print("naive time is: " + str(end-start))
    start = time.time()
    np.dot(a, b)
    end = time.time()
    numpy_times.append(end - start)
    sizes.append(i)
    print("numpy time is: " + str(end-start))
    i = i * 2
    
    
    
plt.plot(sizes, naive_times, label='Naive')
plt.plot(sizes, numpy_times, label='NumPy')

plt.xlabel('Matrix Size (n)')
plt.ylabel('Runtime (seconds)')
plt.title('Matrix Multiplication Runtime')

plt.legend()
plt.show()
# Out:
# i = 3
# naive time is: 2.765655517578125e-05
# numpy time is: 0.00028061866760253906
# i = 6
# naive time is: 6.508827209472656e-05
# numpy time is: 6.031990051269531e-05
# i = 12
# naive time is: 0.00036144256591796875
# numpy time is: 1.2874603271484375e-05
# i = 24
# naive time is: 0.0027272701263427734
# numpy time is: 0.0013740062713623047
# i = 48
# naive time is: 0.019609928131103516
# numpy time is: 0.00035309791564941406
# i = 96
# naive time is: 0.1537940502166748
# numpy time is: 0.0005078315734863281
# i = 192
# naive time is: 1.2663359642028809
# numpy time is: 0.0007967948913574219
# i = 384
# naive time is: 10.517857074737549
# numpy time is: 0.0033173561096191406
