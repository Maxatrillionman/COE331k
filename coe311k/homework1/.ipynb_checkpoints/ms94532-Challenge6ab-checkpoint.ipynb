# %%
import numpy as np

def jacobi(A, b, x0, tol, max_iterations):
    absError = []
    n = len(b)
    x = x0.copy()

    for k in range(max_iterations):
        x_new = np.zeros_like(x)

        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]
            
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k

        x = x_new

    return x, max_iterations

# %%
import numpy as np

def gauss_seidel(A, b, x0, tol, max_iterations):
    absError = []
    
    n = len(b)
    x = x0.copy()

    for k in range(max_iterations):
        x_new = x.copy()

        for i in range(n):
            s1 = sum(A[i][j] * x_new[j] for j in range(i))
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n))
            x_new[i] = (b[i] - s1 - s2) / A[i][i]

        

        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k

        
        x = x_new
        
        

    return x, max_iterations

# %%
##Challenge A - Copied from Homework but changes values + added time
import time 
A = np.array([
    [10, -1,  2,  0,  0],
    [-1, 11, -1,  3,  0],
    [ 2, -1, 10, -1,  0],
    [ 0,  3, -1,  8, -2],
    [ 0,  0,  0, -2,  9]
], dtype=float)


b = np.array([
    14,
    30,
    26,
    25,
    37
], dtype=float)

x0 = np.zeros_like(b)
beg = time.time()
x, max_iterations = jacobi(A, b, x0, 1e-6, 102)
end = time.time()

print("Jacobi")
print(x)

print("Number of iterations: ")
print(max_iterations)
print("Time: ")
print(end - beg)
print(" ")
print("Gauss-seidel")
beg = time.time()
x, max_iterations = gauss_seidel(A, b, x0, 1e-6, 102)
end = time.time()
print(x)

print("Number of iterations: ")
print(max_iterations)
print("Time: ")
print(end-beg)
# Out:
# Jacobi
# [0.99999995 2.00000025 2.99999986 4.00000008 4.99999983]
# Number of iterations:
# 18
# Time:
# 0.001253366470336914
#
# Gauss-seidel
# [1.00000003 2.00000002 2.99999999 3.99999998 5.        ]
# Number of iterations:
# 10
# Time:
# 0.0005884170532226562

# %%
#Challenge B
A = np.array([
    [1, 2, 3, 0, 0],
    [2, 1, 2, 3, 0],
    [3, 2, 1, 2, 3],
    [0, 3, 2, 1, 2],
    [0, 0, 3, 2, 1]
], dtype=float)

b = np.array([
    14,
    22,
    33,
    26,
    22
], dtype=float)

x0 = np.zeros_like(b)
beg = time.time()
x, max_iterations = jacobi(A, b, x0, 1e-6, 102)
end = time.time()


if (max_iterations < 102):
    print("Jacobi")
    print(x)
    print("Number of iterations: ")
    print(max_iterations)
    print("Time: ")
    print(end - beg)
    print(" ")
    print("Gauss-seidel")
    beg = time.time()
    x, max_iterations = gauss_seidel(A, b, x0, 1e-6, 102)
    end = time.time()
    print(x)

    print("Number of iterations: ")
    print(max_iterations)
    print("Time: ")
    print(end-beg)
##elif (max_iterations == 101):
 ##   print("Series Diverges")
    
##Since the series diverges, however if results still printed it would give the following : 
##Jacobi
##[-1.73109267e+87 -2.14454161e+87 -2.66956371e+87 -2.14454161e+87
 ##-1.73109267e+87]
##Number of iterations: 
##102
##Time: 
##0.0056302547454833984
 
##Gauss-seidel
##[ 2.22100535e+115 -6.45440763e+115  4.33659236e+115  1.09561800e+116
## -3.49221370e+116]
##Number of iterations: 
#102
#Time: 
#0.004311323165893555
