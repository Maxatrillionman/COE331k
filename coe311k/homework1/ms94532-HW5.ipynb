# %%
def leastSquare (vector1, vector2): ##My equation; used Chatgpt to find notation bug (.length error)
    
    xtotal = 0 
    ytotal = 0
    xy = 0 
    xSquared = 0

    
    for i in range (len(vector1)):
        xtotal = xtotal + vector1[i]
        ytotal = ytotal + vector2[i]
        
        xy = xy + vector1[i] * vector2[i]
        xSquared = xSquared + (vector1[i] * vector1[i])
    
    return ((len(vector1) * (xy) - (xtotal)*(ytotal)) / (len(vector1) * xSquared - (xtotal * xtotal)))

# %%
Slope = 8
Intercept = 4

X = np.arange(0, 1.01, 0.01)

Y = Slope*X + Intercept + (np.random.rand(len(X)) - 0.5)*0.2

mySlope = leastSquare(X, Y)

myIntercept = np.mean(Y) - mySlope*np.mean(X)

print("My function ")
print("Slope: ")
print(mySlope)
print("Intercept:")
print(myIntercept)

A = np.vstack([X, np.ones(len(X))]).T
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]

print("Numpy Least Squares")
print("Slope:")
print(m)
print("Intercept:")
print(c)

predictY = mySlope*X + myIntercept

resid = Y - predictY

print("Residuals:")
print(resid)

largest = np.argmax(np.abs(resid))
smallest = np.argmin(np.abs(resid))

print("Largest residual point:", X[largest], Y[largest])
print("Smallest residual point:", X[smallest], Y[smallest])

plt.scatter(X, Y)

plt.plot(X, predictY)

plt.plot(X, m*X + c)

plt.show()
# Out:
# My function
# Slope:
# 7.987621104247424
# Intercept:
# 4.008916627737495
# Numpy Least Squares
# Slope:
# 7.9876211042474345
# Intercept:
# 4.00891662773749
# Residuals:
# [ 0.02332221  0.07081715  0.0666057  -0.04930641  0.06029453  0.06132713
#  -0.05284396 -0.08989027 -0.03464257 -0.08383108 -0.04466781  0.05964462
#  -0.07063802  0.06824085 -0.09725365 -0.03437119 -0.03922613 -0.02488176
#   0.07540435 -0.07245847 -0.03099499  0.01168022  0.04659057  0.08955006
#   0.03322682 -0.04748087  0.07143558  0.08149991 -0.0488699   0.0335683
#   0.09194394 -0.02014312 -0.05444915  0.01974037 -0.0176085   0.07639052
#   0.01557596  0.02304511  0.07023557 -0.00324442 -0.05967291 -0.08918625
#   0.08793374 -0.09223534  0.04103663 -0.06662896 -0.05807272  0.08172214
#   0.08605446  0.07711802  0.09500915 -0.04406446 -0.09063863 -0.03719966
#   0.00919882  0.02643238 -0.03372623 -0.06293324 -0.06632766 -0.03501544
#   0.0173142   0.01324467  0.0859284  -0.05018023 -0.01759496 -0.08550181
#   0.01447179  0.03271109 -0.03789167 -0.03310117 -0.05439955  0.01021615
#   0.01035396  0.01521293  0.06215803  0.08780195 -0.0253349  -0.02941014
#  -0.04633654  0.01700112 -0.07029199 -0.08237753 -0.04222256  0.07259728
#  -0.02376385 -0.01821386  0.09860852 -0.04462914  0.00405649 -0.09663604
#  -0.09206565  0.01256469  0.07661431 -0.03726758  0.05959035  0.00137823
#   0.07575251  0.0564717   0.02868801  0.09248342 -0.06014164]
# Largest residual point: 0.86 10.97687929942972
# Smallest residual point: 0.9500000000000001 11.598534903131943
